# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,WordNetLemmatizer
import string

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Muthu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Muthu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Muthu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Muthu\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Muthu\AppData\Roaming\nltk_data...
# True

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Muthu\Downloads\chatgpt_reviews - chatgpt_reviews.csv")

# %%
df.head()
# Out:
#          date                 title  \
# 0   2/15/2025            Impressive
# 1  10/16/2024         Waste of Time
# 2  10/16/2024         Waste of Time
# 3  12/21/2024          Not Accurate
# 4   3/23/2025  Fantastic Experience
#
#                                               review  rating       username  \
# 0  Mother former community upon vote fact. Sure s...       2          ybass
# 1  General paper understand main. Or age half won...       5        glenn33
# 2  Here situation his high stage. Agree certainly...       4       debbie27
# 3  Rule court behind growth reality. Tonight whos...       1  hannahrussell
# 4  Case opportunity season road write. Effort gre...       3        cnorton
#
#    helpful_votes  review_length platform language   location  version  \
# 0             68             78   Mobile       es     Canada      3.0
# 1             71            193      Web       de      India      4.1
# 2             66            184      Web       hi      India      4.1
# 3              5            193      Web       fr     Canada      4.0
# 4             71            131      Web       hi  Australia      4.1
#
#   verified_purchase
# 0                No
# 1               Yes
# 2               Yes
# 3               Yes
# 4                No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               10000 non-null  object
#  1   title              10000 non-null  object
#  2   review             10000 non-null  object
#  3   rating             10000 non-null  int64
#  4   username           10000 non-null  object
#  5   helpful_votes      10000 non-null  int64
#  6   review_length      10000 non-null  int64
#  7   platform           10000 non-null  object
#  8   language           10000 non-null  object
#  9   location           10000 non-null  object
#  10  version            10000 non-null  float64
#  11  verified_purchase  10000 non-null  object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 937.6+ KB

# %%
df.columns
# Out:
# Index(['date', 'title', 'review', 'rating', 'username', 'helpful_votes',
#        'review_length', 'platform', 'language', 'location', 'version',
#        'verified_purchase'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.dtypes
# Out:
# date                  object
# title                 object
# review                object
# rating                 int64
# username              object
# helpful_votes          int64
# review_length          int64
# platform              object
# language              object
# location              object
# version              float64
# verified_purchase     object
# dtype: object

# %%
df.isna().sum()
# Out:
# date                 0
# title                0
# review               0
# rating               0
# username             0
# helpful_votes        0
# review_length        0
# platform             0
# language             0
# location             0
# version              0
# verified_purchase    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              rating  helpful_votes  review_length       version
# count  10000.000000   10000.000000   10000.000000  10000.000000
# mean       2.987000      50.347800     147.034000      3.651070
# std        1.424161      28.914613      34.911708      0.438935
# min        1.000000       0.000000      30.000000      3.000000
# 25%        2.000000      25.000000     122.000000      3.500000
# 50%        3.000000      50.000000     151.000000      4.000000
# 75%        4.000000      75.000000     176.000000      4.100000
# max        5.000000     100.000000     199.000000      4.100000

# %%
df.describe(include='object')
# Out:
#              date  title                                             review  \
# count       10000  10000                                              10000
# unique        366     10                                              10000
# top     1/10/2025  Buggy  Mother former community upon vote fact. Sure s...
# freq           44   1037                                                  1
#
#          username platform language location verified_purchase
# count       10000    10000    10000    10000             10000
# unique       9460        2        5        6                 2
# top     owilliams   Mobile       en   Canada                No
# freq            6     5011     2016     1711              5116

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
''' Preprocesses text by performing tokenization, punctuation removal,stopword removal, stemming, and lemmatization.'''
def preprocess_text(text):
    
    # Sentences Tokenization
    sentences = sent_tokenize(text)

    # Words Tokenization
    words = word_tokenize(text)

    # Removing Punctuations 
    words = [word for word in words if word not in string.punctuation] 

    # Remove Stopwords
    stop_words = set(stopwords.words("english"))
    words = [word for word in words if word.lower() not in stop_words ]

    #stemming
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in words]

    #Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

    return {
        "sentences":sentences,
        "tokenized_words":words,
        "stemmed_words":stemmed_words,
        "lemmatized_words":lemmatized_words
    }

# %%
df["text"] = df["review"].apply(lambda x: preprocess_text(str(x)))
df
# Out:
#            date                 title  \
# 0    2025-02-15            Impressive
# 1    2024-10-16         Waste of Time
# 2    2024-10-16         Waste of Time
# 3    2024-12-21          Not Accurate
# 4    2025-03-23  Fantastic Experience
# ...         ...                   ...
# 9995 2024-06-13          Very Helpful
# 9996 2024-07-16                 Buggy
# 9997 2024-07-22          Not Accurate
# 9998 2024-05-24     Needs Improvement
# 9999 2025-02-17  Fantastic Experience
#
#                                                  review  rating  \
# 0     Mother former community upon vote fact. Sure s...       2
# 1     General paper understand main. Or age half won...       5
# 2     Here situation his high stage. Agree certainly...       4
# 3     Rule court behind growth reality. Tonight whos...       1
# 4     Case opportunity season road write. Effort gre...       3
# ...                                                 ...     ...
# 9995  Little section hit her through. Likely job ind...       5
# 9996  Throw with record relationship help reduce vot...       3
# 9997  Within nothing study charge all. Toward milita...       3
# 9998  Rule kitchen trouble cultural.\nDeep manage ad...       3
# 9999  Resource plant behind vote its try laugh. Othe...       2
#
#            username  helpful_votes  review_length platform language  \
# 0             ybass             68             78   Mobile       es
# 1           glenn33             71            193      Web       de
# 2          debbie27             66            184      Web       hi
# 3     hannahrussell              5            193      Web       fr
# 4           cnorton             71            131      Web       hi
# ...             ...            ...            ...      ...      ...
# 9995         john32             30             83      Web       de
# 9996      michael25             68            189   Mobile       es
# 9997         sean13             10            185      Web       de
# 9998         pjones             48            163   Mobile       fr
# 9999  brownadrienne             61             81      Web       en
#
#        location  version verified_purchase  \
# 0        Canada      3.0                No
# 1         India      4.1               Yes
# 2         India      4.1               Yes
# 3        Canada      4.0               Yes
# 4     Australia      4.1                No
# ...         ...      ...               ...
# 9995  Australia      3.0                No
# 9996    Germany      3.5               Yes
# 9997      India      3.0               Yes
# 9998         UK      3.0               Yes
# 9999    Germany      3.5               Yes
#
#                                                    text
# 0     {'sentences': ['Mother former community upon v...
# 1     {'sentences': ['General paper understand main....
# 2     {'sentences': ['Here situation his high stage....
# 3     {'sentences': ['Rule court behind growth reali...
# 4     {'sentences': ['Case opportunity season road w...
# ...                                                 ...
# 9995  {'sentences': ['Little section hit her through...
# 9996  {'sentences': ['Throw with record relationship...
# 9997  {'sentences': ['Within nothing study charge al...
# 9998  {'sentences': ['Rule kitchen trouble cultural....
# 9999  {'sentences': ['Resource plant behind vote its...
#
# [10000 rows x 13 columns]

# %%
#Check Word Frequency

from collections import Counter

all_words = [word for sublist in df["text"].apply(lambda x:x["tokenized_words"]) for word in sublist]
word_freq = Counter(all_words)
print(word_freq.most_common(10))
# Out:
# [('American', 246), ('Congress', 245), ('week', 231), ('operation', 230), ('claim', 224), ('Mr', 223), ('Mrs', 222), ('ten', 220), ('east', 220), ('read', 219)]

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\muthu\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\muthu\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\muthu\anaconda3\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muthu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\muthu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muthu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\muthu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\muthu\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
#Visualize Word Cloud

from wordcloud import WordCloud

wordcloud = WordCloud(width=800, height=400,background_color='white').generate(" ".join(all_words))
plt.figure(figsize=(10,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\muthu\anaconda3\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\muthu\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\muthu\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\muthu\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\muthu\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\muthu\appdata\roaming\python\python312\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.19.0

# %%
#Sentiment Analysis
You can classify reviews as positive, neutral, or negative using a sentiment analysis model.

# %%
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(" ".join(text['lemmatized_words']))
    return "Positive" if analysis.sentiment.polarity > 0 else "Negative" if analysis.sentiment.polarity < 0 else "Neutral"

df["sentiment"] = df["text"].apply(get_sentiment)
df["sentiment"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sentiment'>

# %%
df
# Out:
#            date                 title  \
# 0    2025-02-15            Impressive
# 1    2024-10-16         Waste of Time
# 2    2024-10-16         Waste of Time
# 3    2024-12-21          Not Accurate
# 4    2025-03-23  Fantastic Experience
# ...         ...                   ...
# 9995 2024-06-13          Very Helpful
# 9996 2024-07-16                 Buggy
# 9997 2024-07-22          Not Accurate
# 9998 2024-05-24     Needs Improvement
# 9999 2025-02-17  Fantastic Experience
#
#                                                  review  rating  \
# 0     Mother former community upon vote fact. Sure s...       2
# 1     General paper understand main. Or age half won...       5
# 2     Here situation his high stage. Agree certainly...       4
# 3     Rule court behind growth reality. Tonight whos...       1
# 4     Case opportunity season road write. Effort gre...       3
# ...                                                 ...     ...
# 9995  Little section hit her through. Likely job ind...       5
# 9996  Throw with record relationship help reduce vot...       3
# 9997  Within nothing study charge all. Toward milita...       3
# 9998  Rule kitchen trouble cultural.\nDeep manage ad...       3
# 9999  Resource plant behind vote its try laugh. Othe...       2
#
#            username  helpful_votes  review_length platform language  \
# 0             ybass             68             78   Mobile       es
# 1           glenn33             71            193      Web       de
# 2          debbie27             66            184      Web       hi
# 3     hannahrussell              5            193      Web       fr
# 4           cnorton             71            131      Web       hi
# ...             ...            ...            ...      ...      ...
# 9995         john32             30             83      Web       de
# 9996      michael25             68            189   Mobile       es
# 9997         sean13             10            185      Web       de
# 9998         pjones             48            163   Mobile       fr
# 9999  brownadrienne             61             81      Web       en
#
#        location  version verified_purchase  \
# 0        Canada      3.0                No
# 1         India      4.1               Yes
# 2         India      4.1               Yes
# 3        Canada      4.0               Yes
# 4     Australia      4.1                No
# ...         ...      ...               ...
# 9995  Australia      3.0                No
# 9996    Germany      3.5               Yes
# 9997      India      3.0               Yes
# 9998         UK      3.0               Yes
# 9999    Germany      3.5               Yes
#
#                                                    text sentiment
# 0     {'sentences': ['Mother former community upon v...  Positive
# 1     {'sentences': ['General paper understand main....  Positive
# 2     {'sentences': ['Here situation his high stage....  Positive
# 3     {'sentences': ['Rule court behind growth reali...  Negative
# 4     {'sentences': ['Case opportunity season road w...  Positive
# ...                                                 ...       ...
# 9995  {'sentences': ['Little section hit her through...  Negative
# 9996  {'sentences': ['Throw with record relationship...  Negative
# 9997  {'sentences': ['Within nothing study charge al...   Neutral
# 9998  {'sentences': ['Rule kitchen trouble cultural....  Positive
# 9999  {'sentences': ['Resource plant behind vote its...  Negative
#
# [10000 rows x 14 columns]

# %%
#Save the Processed Dataset
#Save as CSV

df.to_csv("processed_reviews.csv", index=False)
print("Processed dataset saved as 'processed_reviews.csv'")

#Processed dataset saved as 'processed_reviews.csv'
# Out:
# Processed dataset saved as 'processed_reviews.csv'

# %%
#Save as Pickle (Faster for Large Data)

df.to_pickle("processed_reviews.pkl")
print("Processed dataset saved as 'processed_reviews.pkl'")

#Processed dataset saved as 'processed_reviews.pkl'
# Out:
# Processed dataset saved as 'processed_reviews.pkl'
